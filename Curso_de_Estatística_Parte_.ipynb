# %% [markdown]
# <a href="https://colab.research.google.com/github/Maiagit2024/Airbnb-Analytics/blob/main/Curso_de_Estat%C3%ADstica_Parte_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***
# # <font color=green size=10>CURSO DE ESTATÍSTICA - PARTE 1</font>
# ***

# %% [markdown]
# # <font color=green>1 CONHECENDO OS DADOS</font>
# ***

# %% [markdown]
# ## <font color=green>1.1 Dataset do projeto</font>
# ***

# %% [markdown]
# ### Pesquisa Nacional por Amostra de Domicílios - 2015
#
# A <b>Pesquisa Nacional por Amostra de Domicílios - PNAD</b> investiga anualmente, de forma permanente, características gerais da população, de educação, trabalho, rendimento e habitação e outras, com periodicidade variável, de acordo com as necessidades de informação para o país, como as características sobre migração, fecundidade, nupcialidade, saúde, segurança alimentar, entre outros temas. O levantamento dessas estatísticas constitui, ao longo dos 49 anos de realização da pesquisa, um importante instrumento para formulação, validação e avaliação de políticas orientadas para o desenvolvimento socioeconômico e a melhoria das condições de vida no Brasil.

# %% [markdown]
# ### Fonte dos Dados
#
# https://ww2.ibge.gov.br/home/estatistica/populacao/trabalhoerendimento/pnad2015/microdados.shtm

# %%
import pandas as pd

# %%
from google.colab import data_table
import vega_datasets

# %%
df.head(5)
# Out:
#    UF  Sexo  Idade  Cor  Anos de Estudo  Renda    Altura
# 0  11     0     23    8              12    800  1.603808
# 1  11     1     23    2              12   1150  1.739790
# 2  11     1     35    8              15    880  1.760444
# 3  11     0     46    2               6   3500  1.783158
# 4  11     1     47    8               9    150  1.690631

# %%
print(f"Altura minima: {dados.Altura.min():.2f} até Altura maxima: {dados.Altura.max():.2f}")
# Out:
# Altura minima: 1.34 até Altura maxima: 2.03

# %% [markdown]
# ### Variáveis utilizadas
#
# > ### Renda
# > ***
#
# Rendimento mensal do trabalho principal para pessoas de 10 anos ou mais de idade.
#
# > ### Idade
# > ***
#
# Idade do morador na data de referência em anos.
#
# > ### Altura (elaboração própria)
# > ***
#
# Altura do morador em metros.
#
# > ### UF
# > ***
#
# |Código|Descrição|
# |---|---|
# |11|Rondônia|
# |12|Acre|
# |13|Amazonas|
# |14|Roraima|
# |15|Pará|
# |16|Amapá|
# |17|Tocantins|
# |21|Maranhão|
# |22|Piauí|
# |23|Ceará|
# |24|Rio Grande do Norte|
# |25|Paraíba|
# |26|Pernambuco|
# |27|Alagoas|
# |28|Sergipe|
# |29|Bahia|
# |31|Minas Gerais|
# |32|Espírito Santo|
# |33|Rio de Janeiro|
# |35|São Paulo|
# |41|Paraná|
# |42|Santa Catarina|
# |43|Rio Grande do Sul|
# |50|Mato Grosso do Sul|
# |51|Mato Grosso|
# |52|Goiás|
# |53|Distrito Federal|
#
# > ### Sexo
# > ***
#
# |Código|Descrição|
# |---|---|
# |0|Masculino|
# |1|Feminino|
#
# > ### Anos de Estudo
# > ***
#
# |Código|Descrição|
# |---|---|
# |1|Sem instrução e menos de 1 ano|
# |2|1 ano|
# |3|2 anos|
# |4|3 anos|
# |5|4 anos|
# |6|5 anos|
# |7|6 anos|
# |8|7 anos|
# |9|8 anos|
# |10|9 anos|
# |11|10 anos|
# |12|11 anos|
# |13|12 anos|
# |14|13 anos|
# |15|14 anos|
# |16|15 anos ou mais|
# |17|Não determinados|
# ||Não aplicável|
#
# > ### Cor
# > ***
#
# |Código|Descrição|
# |---|---|
# |0|Indígena|
# |2|Branca|
# |4|Preta|
# |6|Amarela|
# |8|Parda|
# |9|Sem declaração|

# %% [markdown]
# #### <font color='red'>Observação</font>
# ***
# > Os seguintes tratamentos foram realizados nos dados originais:
# > 1. Foram eliminados os registros onde a <b>Renda</b> era inválida (999 999 999 999);
# > 2. Foram eliminados os registros onde a <b>Renda</b> era missing;
# > 3. Foram considerados somente os registros das <b>Pessoas de Referência</b> de cada domicílio (responsável pelo domicílio).

# %% [markdown]
# ### Importando pandas e lendo o dataset do projeto
#
# https://pandas.pydata.org/

# %%
import pandas as pd

# %%
dados = pd.read_csv("dados.csv")

# %%
dados.head(5
           )
# Out:
#    UF  Sexo  Idade  Cor  Anos de Estudo  Renda    Altura
# 0  11     0     23    8              12    800  1.603808
# 1  11     1     23    2              12   1150  1.739790
# 2  11     1     35    8              15    880  1.760444
# 3  11     0     46    2               6   3500  1.783158
# 4  11     1     47    8               9    150  1.690631

# %% [markdown]
# ## <font color=green>1.2 Tipos de dados</font>
# ***

# %% [markdown]
# ### Variáveis qualitativas ordinais
#
# ► Variáveis que podem ser ordenadas ou hierarquizardas

# %%
sorted(dados["Idade"].unique())
# Out:
# [np.int64(13),
#  np.int64(14),
#  np.int64(15),
#  np.int64(16),
#  np.int64(17),
#  np.int64(18),
#  np.int64(19),
#  np.int64(20),
#  np.int64(21),
#  np.int64(22),
#  np.int64(23),
#  np.int64(24),
#  np.int64(25),
#  np.int64(26),
#  np.int64(27),
#  np.int64(28),
#  np.int64(29),
#  np.int64(30),
#  np.int64(31),
#  np.int64(32),
#  np.int64(33),
#  np.int64(34),
#  np.int64(35),
#  np.int64(36),
#  np.int64(37),
#  np.int64(38),
#  np.int64(39),
#  np.int64(40),
#  np.int64(41),
#  np.int64(42),
#  np.int64(43),
#  np.int64(44),
#  np.int64(45),
#  np.int64(46),
#  np.int64(47),
#  np.int64(48),
#  np.int64(49),
#  np.int64(50),
#  np.int64(51),
#  np.int64(52),
#  np.int64(53),
#  np.int64(54),
#  np.int64(55),
#  np.int64(56),
#  np.int64(57),
#  np.int64(58),
#  np.int64(59),
#  np.int64(60),
#  np.int64(61),
#  np.int64(62),
#  np.int64(63),
#  np.int64(64),
#  np.int64(65),
#  np.int64(66),
#  np.int64(67),
#  np.int64(68),
#  np.int64(69),
#  np.int64(70),
# ...

# %% [markdown]
# ### Variáveis qualitativas nominais
#
# ► Variáveis que não podem ser ordenadas ou hierarquizardas

# %%
sorted(dados["Cor"].unique())
# Out:
# [np.int64(0), np.int64(2), np.int64(4), np.int64(6), np.int64(8)]

# %%
sorted(dados["Anos de Estudo"].unique())
# Out:
# [np.int64(1),
#  np.int64(2),
#  np.int64(3),
#  np.int64(4),
#  np.int64(5),
#  np.int64(6),
#  np.int64(7),
#  np.int64(8),
#  np.int64(9),
#  np.int64(10),
#  np.int64(11),
#  np.int64(12),
#  np.int64(13),
#  np.int64(14),
#  np.int64(15),
#  np.int64(16),
#  np.int64(17)]

# %%
sorted(dados["UF"].unique())
# Out:
# [np.int64(11),
#  np.int64(12),
#  np.int64(13),
#  np.int64(14),
#  np.int64(15),
#  np.int64(16),
#  np.int64(17),
#  np.int64(21),
#  np.int64(22),
#  np.int64(23),
#  np.int64(24),
#  np.int64(25),
#  np.int64(26),
#  np.int64(27),
#  np.int64(28),
#  np.int64(29),
#  np.int64(31),
#  np.int64(32),
#  np.int64(33),
#  np.int64(35),
#  np.int64(41),
#  np.int64(42),
#  np.int64(43),
#  np.int64(50),
#  np.int64(51),
#  np.int64(52),
#  np.int64(53)]

# %% [markdown]
# ### Variáveis quantitativas discretas
#
# ► Variáveis que representam uma contagem onde os valores possíveis formam um conjunto finito ou enumerável.

# %%
dados.Idade.min()
# Out:
# 13

# %% [markdown]
# #### <font color='red'>Observação</font>
# ***
# > A variável idade pode ser classificada de três formas distintas:
# > 1. <b>QUANTITATIVA DISCRETA</b> - quando representa anos completos (números inteiros);
# > 2. <b>QUANTITATIVA CONTÍNUA</b> - quando representa a idade exata, sendo representado por frações de anos; e
# > 3. <b>QUALITATIVA ORDINAL</b> - quando representa faixas de idade.

# %% [markdown]
# ### Variáveis quantitativas contínuas
#
# ► Variáveis que representam uma contagem ou mensuração que assumem valores em uma escala contínua (números reais).

# %%
print(f"Altura minima: {dados.Altura.min():.2f} até Altura maxima: {dados.Altura.max():.2f}")
# Out:
# Altura minima: 1.34 até Altura maxima: 2.03

# %% [markdown]
# ### Classificação de uma variável
# <img src='https://caelum-online-public.s3.amazonaws.com/1177-estatistica-parte1/01/img001.png' width='70%'>

# %% [markdown]
# # <font color=green>2 DISTRIBUIÇÃO DE FREQUÊNCIAS</font>
# ***
#
# O primeiro passo em um trabalho de análise é o conhecimento do comportamento das variáveis envolvidas no estudo. Utilizando técnicas estatísticas como as análises das <b>DISTRIBUIÇÕES DE FREQUÊNCIAS</b> e <b>HISTOGRAMAS</b> podemos avaliar melhor a forma como os fenômenos em estudo se distribuem.

# %% [markdown]
# ## <font color=green>2.1 Distribuição de frequências para variáveis qualitativas</font>
# ***

# %% [markdown]
# ### Método 1

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/version/0.22/generated/pandas.Series.value_counts.html

# %%
import pandas as pd

# %%
dados = pd.read_csv("dados.csv")

# %%
dados = df

# %%
dados.head(10)
# Out:
#    UF  Sexo  Idade  Cor  Anos de Estudo  Renda    Altura
# 0  11     0     23    8              12    800  1.603808
# 1  11     1     23    2              12   1150  1.739790
# 2  11     1     35    8              15    880  1.760444
# 3  11     0     46    2               6   3500  1.783158
# 4  11     1     47    8               9    150  1.690631
# 5  11     1     34    8              12    790  1.637906
# 6  11     0     57    8              12   3150  1.570078
# 7  11     1     60    8              12   1700  1.608495
# 8  11     1     50    4              14   1800  1.780329
# 9  11     0     26    8              12   1150  1.793203

# %%
dados["Sexo"].value_counts(normalize=True) * 100
# Out:
# Sexo
# 0    69.299844
# 1    30.700156
# Name: proportion, dtype: float64

# %%
dados["Idade"].value_counts()
# Out:
# Idade
# 40    2263
# 45    2250
# 37    2235
# 43    2213
# 35    2206
#       ...
# 95       1
# 97       1
# 94       1
# 14       1
# 99       1
# Name: count, Length: 84, dtype: int64

# %%
dados ["Sexo"].value_counts()
# Out:
# Sexo
# 0    53250
# 1    23590
# Name: count, dtype: int64

# %%
frequencia = dados ["Sexo"].value_counts()

# %%
percentual = dados["Sexo"].value_counts(normalize=True) * 100

# %%
dis_fre_qualitativas = pd.DataFrame({"Frequencia": frequencia, "Porcentagem (%)": percentual})

# %%
dis_fre_qualitativas
# Out:
#       Frequencia  Porcentagem (%)
# Sexo
# 0          24376        69.057737
# 1          10922        30.942263

# %%
dis_fre_qualitativas.rename(index = {0:"Masculino",1: "Feminino"},inplace= True)
dis_fre_qualitativas.rename_axis(axis="columns",inplace = True)

# %%
dis_fre_qualitativas
# Out:
#            Frequencia  Porcentagem (%)
# Sexo
# Masculino       24376        69.057737
# Feminino        10922        30.942263

# %% [markdown]
# ### Método 2

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/version/0.22/generated/pandas.crosstab.html

# %%
sexo = {0:"Masculino",
        1:"Feminino"}

cor = {0:"Indigena",
       2:"Branca",
       4:"Preta",
       6:"Amarela",
       8:"Parda"}

Idade = {1:"Sem instrução e menos de 1 ano",
2:"1 ano",
3:"2 anos",
4:"3 anos",
5	:"4 anos",
6	:"5 anos",
7	:"6 anos",
8	:"7 anos",
9	:"8 anos",
10:	"9 anos",
11:	"10 anos",
12:	"11 anos",
13:	"12 anos",
14:	"13 anos",
15:	"14 anos",
16:	"15 anos ou mais",
17:	"Não determinados Não aplicável"}

UF = {
11:	"Rondônia",
12:	"Acre",
13:	"Amazonas",
14:	"Roraima",
15:	"Pará",
16:	"Amapá",
17:	"Tocantins",
21:	"Maranhão",
22:	"Piauí",
23:	"Ceará",
24:	"Rio Grande do Norte",
25:	"Paraíba",
26:	"Pernambuco",
27:	"Alagoas",
28:	"Sergipe",
29:	"Minas Gerais",
32: "Espírito Santo",
33:	"Rio de Janeiro",
35:	"São Paulo",
41:	"Paraná",
42:	"Santa Catarina",
43:	"Rio Grande do Sul",
50:	"Mato Grosso do Sul",
51:	"Mato Grosso",
52:	"Goiás",
53:	"Distrito Federal"}

# %%
frequencia = pd.crosstab(dados.Sexo,
                         dados.Cor,
                         normalize=True)* 100
frequencia.rename(index = sexo,inplace = True)
frequencia.rename(columns = cor,inplace = True)
frequencia
# Out:
# Cor        Indigena     Branca     Preta   Amarela      Parda
# Sexo
# Masculino  0.333160  28.883394  7.160333  0.305830  32.617126
# Feminino   0.131442  12.520822  3.759761  0.152264  14.135867

# %%
percentual = pd.crosstab(dados.Sexo,
                         dados.Cor,
                         aggfunc="mean",
                         values = dados.Renda)* 100
percentual.rename(index = sexo,inplace = True)
percentual.rename(columns = cor,inplace = True)
percentual
# Out:
# Cor             Indigena         Branca          Preta        Amarela  \
# Sexo
# Masculino  108171.093750  292574.443543  160386.168666  475825.106383
# Feminino   246438.613861  210986.674982  113459.640014  302734.188034
#
# Cor                Parda
# Sexo
# Masculino  165957.742489
# Feminino   117675.851593

# %%
# @title
frequencia_cidade_genero = pd.crosstab(dados.Sexo,
                                      dados.UF)
frequencia_cidade_genero.rename(index=sexo, inplace=True)
frequencia_cidade_genero.rename(columns=UF, inplace=True)
frequencia_cidade_genero
# Out:
# UF         Rondônia  Acre  Amazonas  Roraima  Pará  Amapá  Tocantins  \
# Sexo
# Masculino      1138   698      1518      354  3146    330        958
# Feminino        399   239       688      186  1303    182        348
#
# UF         Maranhão  Piauí  Ceará  ...  Espírito Santo  Rio de Janeiro  \
# Sexo                               ...
# Masculino      1197    857   2227  ...            1098            3618
# Feminino        590    354   1132  ...             413            1938
#
# UF         São Paulo  Paraná  Santa Catarina  Rio Grande do Sul  \
# Sexo
# Masculino       5892    3129            1723               4246
# Feminino        2652    1227             552               2076
#
# UF         Mato Grosso do Sul  Mato Grosso  Goiás  Distrito Federal
# Sexo
# Masculino                 987         1296   2580              1253
# Feminino                  453          504    898               801
#
# [2 rows x 27 columns]

# %%
frequencia_cidade_genero
# Out:
# UF         Rondônia  Acre  Amazonas  Roraima  Pará  Amapá  Tocantins  \
# Sexo
# Masculino      1138   698      1518      354  3146    330        958
# Feminino        399   239       688      186  1303    182        348
#
# UF         Maranhão  Piauí  Ceará  ...  Espírito Santo  Rio de Janeiro  \
# Sexo                               ...
# Masculino      1197    857   2227  ...            1098            3618
# Feminino        590    354   1132  ...             413            1938
#
# UF         São Paulo  Paraná  Santa Catarina  Rio Grande do Sul  \
# Sexo
# Masculino       5892    3129            1723               4246
# Feminino        2652    1227             552               2076
#
# UF         Mato Grosso do Sul  Mato Grosso  Goiás  Distrito Federal
# Sexo
# Masculino                 987         1296   2580              1253
# Feminino                  453          504    898               801
#
# [2 rows x 27 columns]

# %%
from google.colab import data_table
import vega_datasets

# %%
data_table.enable_dataframe_formatter()
frequencia_cidade_genero
# Out:
# ...
# UF         Rondônia  Acre  Amazonas  Roraima  Pará  Amapá  Tocantins  \
# Sexo
# Masculino      1138   698      1518      354  3146    330        958
# Feminino        399   239       688      186  1303    182        348
#
# UF         Maranhão  Piauí  Ceará  ...  Espírito Santo  Rio de Janeiro  \
# Sexo                               ...
# Masculino      1197    857   2227  ...            1098            3618
# Feminino        590    354   1132  ...             413            1938
#
# UF         São Paulo  Paraná  Santa Catarina  Rio Grande do Sul  \
# Sexo
# Masculino       5892    3129            1723               4246
# Feminino        2652    1227             552               2076
#
# UF         Mato Grosso do Sul  Mato Grosso  Goiás  Distrito Federal
# Sexo
# Masculino                 987         1296   2580              1253
# Feminino                  453          504    898               801
#
# [2 rows x 27 columns]

# %%
dados.head(5)
# Out:
#    UF  Sexo  Idade  Cor  Anos de Estudo  Renda    Altura
# 0  11     0     23    8              12    800  1.603808
# 1  11     1     23    2              12   1150  1.739790
# 2  11     1     35    8              15    880  1.760444
# 3  11     0     46    2               6   3500  1.783158
# 4  11     1     47    8               9    150  1.690631

# %% [markdown]
# ## <font color=green>2.2 Distribuição de frequências para variáveis quantitativas (classes personalizadas)</font>
# ***

# %% [markdown]
# ### Passo 1 - Especificar os limites de cada classe
#
# Utilizar a seguinte classificação:
#
# <b>A</b> ► Acima de 20 SM
#
# <b>B</b> ► De 10 a 20 SM
#
# <b>C</b> ► De 4 a 10 SM
#
# <b>D</b> ► De 2 a 4 SM
#
# <b>E</b> ► Até 2 SM
#
# onde <b>SM</b> é o valor do salário mínimo na época. Em nosso caso <b>R$ 788,00</b> (2015):
#
# <b>A</b> ► Acima de 15.760
#
# <b>B</b> ► De 7.880 a 15.760
#
# <b>C</b> ► De 3.152 a 7.880
#
# <b>D</b> ► De 1.576 a 3.152
#
# <b>E</b> ► Até 1.576

# %%
dados.Renda.min()
# Out:
# 0

# %%
dados.Renda.max()
# Out:
# 200000

# %%
classes_renda = [0,1576,3152,7880,15760,20000]

# %%
labels = ['E','D','C','B','A']

# %% [markdown]
# ### Passo 2 - Criar a tabela de frequências

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/version/0.22/generated/pandas.cut.html

# %%
dados.head(5)
# Out:
#    UF  Sexo  Idade  Cor  Anos de Estudo  Renda    Altura
# 0  11     0     23    8              12    800  1.603808
# 1  11     1     23    2              12   1150  1.739790
# 2  11     1     35    8              15    880  1.760444
# 3  11     0     46    2               6   3500  1.783158
# 4  11     1     47    8               9    150  1.690631

# %%
Renda = pd.Series(
  pd.cut(x=dados.Renda,
       bins = classes_renda,
       labels= labels,
       include_lowest= True)
  .value_counts(sort = True)
)
Renda
# Out:
# Renda
# E    49755
# D    16700
# C     7599
# B     2178
# A      349
# Name: count, dtype: int64

# %%
percentual = pd.Series(
       pd.cut(x= df.Renda,
       bins = classes_renda,
       labels= labels,
       include_lowest= True)
       .value_counts(normalize= True)
)
percentual
# Out:
# Renda
# E    0.649704
# D    0.218070
# C    0.099228
# B    0.028440
# A    0.004557
# Name: proportion, dtype: float64

# %%
frequencia_renda_classes = pd.Series(
    pd.cut(x=df.Renda,
       bins = classes_renda,
       labels= labels,
       include_lowest= True)
      .value_counts(sort = True))
dis_fre_quantitativas_rend = pd.DataFrame(
    {"Frequencia": frequencia_renda_classes, "Porcentagem (%)": percentual})
dis_fre_quantitativas_rend
# Out:
#        Frequencia  Porcentagem (%)
# Renda
# E           49755         0.649704
# D           16700         0.218070
# C            7599         0.099228
# B            2178         0.028440
# A             349         0.004557

# %%
dis_fre_quantitativas_rend.sort_index(ascending=False)
# Out:
#        Frequencia  Porcentagem (%)
# Renda
# A             349         0.004557
# B            2178         0.028440
# C            7599         0.099228
# D           16700         0.218070
# E           49755         0.649704

# %%
dados[(dados["Renda"] > 1000) & (dados["Cor"] == 2)]
# Out:
# ...
#        UF  Sexo  Idade  Cor  Anos de Estudo  Renda    Altura
# 1      11     1     23    2              12   1150  1.739790
# 3      11     0     46    2               6   3500  1.783158
# 12     11     1     52    2               6   1200  1.736442
# 14     11     0     45    2              12   2000  1.780450
# 15     11     0     34    2              16   6000  1.711825
# ...    ..   ...    ...  ...             ...    ...       ...
# 76827  53     1     41    2              16  10000  1.696208
# 76828  53     0     62    2              16  10000  1.817097
# 76830  53     0     62    2              16   3500  1.725379
# 76831  53     1     44    2              16  30000  1.783962
# 76832  53     1     49    2              12   5000  1.757146
#
# [21783 rows x 7 columns]

# %%
from matplotlib import pyplot as plt
_df_3['Anos de Estudo'].plot(kind='hist', bins=20, title='Anos de Estudo')
plt.gca().spines[['top', 'right',]].set_visible(False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1648068794.py in <cell line: 0>()
#       1 from matplotlib import pyplot as plt
# ----> 2 _df_3['Anos de Estudo'].plot(kind='hist', bins=20, title='Anos de Estudo')
#       3 plt.gca().spines[['top', 'right',]].set_visible(False)
#
# NameError: name '_df_3' is not defined

# %%
dados[(dados["Renda"] > 1000) & (dados["Cor"]==4)]
# Out:
#        UF  Sexo  Idade  Cor  Anos de Estudo  Renda    Altura
# 8      11     1     50    4              14   1800  1.780329
# 39     11     0     47    4               9   1500  1.672258
# 83     11     0     60    4               1   1400  1.650203
# 90     11     1     29    4              15   1300  1.745392
# 96     11     0     26    4               9   1145  1.717498
# ...    ..   ...    ...  ...             ...    ...       ...
# 76810  53     0     34    4              12   2500  1.802241
# 76813  53     0     35    4               9   2100  1.671112
# 76833  53     0     30    4               6   1900  1.662560
# 76834  53     1     35    4               1   1100  1.741089
# 76836  53     0     30    4               7   1500  1.792934
#
# [4050 rows x 7 columns]

# %% [markdown]
# ## <font color=green>2.3 Distribuição de frequências para variáveis quantitativas (classes de amplitude fixa)</font>
# ***

# %% [markdown]
# ### Importando bibliotecas
#
# http://www.numpy.org/

# %%
import numpy as np

# %% [markdown]
# ### Passo 1 - Difinindo o número de classes

# %% [markdown]
# #### Regra de Sturges
#
# # $$k = 1 + \frac {10}{3}\log_{10}n$$

# %%
n =dados.shape[0]
n
# Out:
# 76840

# %%
k = 1 +(10/3) * np.log10(n)

# %%
k
# Out:
# np.float64(17.285291187298853)

# %%
k = int(k.round(0))

# %%
k
# Out:
# 17

# %% [markdown]
# ### Passo 2 - Criar a tabela de frequências

# %%
# === SEUS INTERVALOS EXATOS (cópia fiel da imagem) ===
bins = [
    200.001, 11764.706, 23292.412, 35294.118, 47058.824,
    58823.529, 70588.235, 82352.941, 94117.647, 105882.353,
    117647.059, 129411.765, 141176.471, 152941.176, 164705.882,
    176470.588, 188235.294, 200000.0
]

# === LABELS BONITOS EM REAIS (formato brasileiro profissional) ===
labels_renda= [
    "Até R$ 11.765",
    "R$ 11.765 - 23.292",
    "R$ 23.292 - 35.294",
    "R$ 35.294 - 47.059",
    "R$ 47.059 - 58.824",
    "R$ 58.824 - 70.588",
    "R$ 70.588 - 82.353",
    "R$ 82.353 - 94.118",
    "R$ 94.118 - 105.882",
    "R$ 105.882 - 117.647",
    "R$ 117.647 - 129.412",
    "R$ 129.412 - 141.176",
    "R$ 141.176 - 152.941",
    "R$ 152.941 - 164.706",
    "R$ 164.706 - 176.471",
    "R$ 176.471 - 188.235",
    "Acima de R$ 188.235"
]

# %%
frequencia = pd.Series(
    pd.cut(x=dados.Renda,
           bins=bins, # Changed from 17 to classes_renda
           include_lowest = True,
           right = True,
           labels=labels)
).value_counts(sort = False
)
frequencia
# Out:
# Renda
# Até R$ 11.765           69972
# R$ 11.765 - 23.292       1021
# R$ 23.292 - 35.294        170
# R$ 35.294 - 47.059         19
# R$ 47.059 - 58.824         16
# R$ 58.824 - 70.588          5
# R$ 70.588 - 82.353          4
# R$ 82.353 - 94.118          1
# R$ 94.118 - 105.882         6
# R$ 105.882 - 117.647        0
# R$ 117.647 - 129.412        1
# R$ 129.412 - 141.176        0
# R$ 141.176 - 152.941        0
# R$ 152.941 - 164.706        0
# R$ 164.706 - 176.471        0
# R$ 176.471 - 188.235        0
# Acima de R$ 188.235         3
# Name: count, dtype: int64

# %%
frequencia
# Out:
# Renda
# Até R$ 11.765           69972
# R$ 11.765 - 23.292       1021
# R$ 23.292 - 35.294        170
# R$ 35.294 - 47.059         19
# R$ 47.059 - 58.824         16
# R$ 58.824 - 70.588          5
# R$ 70.588 - 82.353          4
# R$ 82.353 - 94.118          1
# R$ 94.118 - 105.882         6
# R$ 105.882 - 117.647        0
# R$ 117.647 - 129.412        1
# R$ 129.412 - 141.176        0
# R$ 141.176 - 152.941        0
# R$ 152.941 - 164.706        0
# R$ 164.706 - 176.471        0
# R$ 176.471 - 188.235        0
# Acima de R$ 188.235         3
# Name: count, dtype: int64

# %%
percentual = pd.Series(
    pd.cut(x=dados.Renda,
           bins = bins,
           include_lowest = True)
).value_counts(sort = False, normalize = True)

# %%
percentual
# Out:
# Renda
# (200.0, 11764.706]          0.982504
# (11764.706, 23292.412]      0.014336
# (23292.412, 35294.118]      0.002387
# (35294.118, 47058.824]      0.000267
# (47058.824, 58823.529]      0.000225
# (58823.529, 70588.235]      0.000070
# (70588.235, 82352.941]      0.000056
# (82352.941, 94117.647]      0.000014
# (94117.647, 105882.353]     0.000084
# (105882.353, 117647.059]    0.000000
# (117647.059, 129411.765]    0.000014
# (129411.765, 141176.471]    0.000000
# (141176.471, 152941.176]    0.000000
# (152941.176, 164705.882]    0.000000
# (164705.882, 176470.588]    0.000000
# (176470.588, 188235.294]    0.000000
# (188235.294, 200000.0]      0.000042
# Name: proportion, dtype: float64

# %%
percentual  = (frequencia / frequencia.sum() * 100).round(2)

# %%
dis_fre_quantitativas_amplitude_fixa = pd.DataFrame(
    {"Frequencia": frequencia,"Porcentagem (%)": percentual})

# %%
dis_fre_quantitativas_amplitude_fixa.index.name = "Faixas de Renda"
dis_fre_quantitativas_amplitude_fixa
# Out:
#                       Frequencia  Porcentagem (%)
# Faixas de Renda
# A                            NaN         0.004557
# Acima de R$ 188.235          3.0              NaN
# Até R$ 11.765            69972.0              NaN
# B                            NaN         0.028440
# C                            NaN         0.099228
# D                            NaN         0.218070
# E                            NaN         0.649704
# R$ 105.882 - 117.647         0.0              NaN
# R$ 11.765 - 23.292        1021.0              NaN
# R$ 117.647 - 129.412         1.0              NaN
# R$ 129.412 - 141.176         0.0              NaN
# R$ 141.176 - 152.941         0.0              NaN
# R$ 152.941 - 164.706         0.0              NaN
# R$ 164.706 - 176.471         0.0              NaN
# R$ 176.471 - 188.235         0.0              NaN
# R$ 23.292 - 35.294         170.0              NaN
# R$ 35.294 - 47.059          19.0              NaN
# ...

# %% [markdown]
# ## <font color=green>2.4 Histograma</font>
# ***
#
# O <b>HISTOGRAMA</b> é a representação gráfica de uma distribuição de frequências. É uma gráfico formado por um conjunto de retângulos colocados lado a lado, onde a área de cada retângulo é proporcional à frequência da classe que ele representa.

# %% [markdown]
# ### Importando a biblioteca
#
# https://seaborn.pydata.org/

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
dados = pd.read_csv("dados.csv")

# %%
ax =sns.histplot(dados.Altura)

ax.figure.set_size_inches(12,6)
ax.set_title("Distribuição de frequência - Altura",fontsize  =18 )
ax.set_xlabel('Metros',fontsize = 16)
ax
# Out:
# <Axes: title={'center': 'Distribuição de frequência - Altura'}, xlabel='Metros', ylabel='Count'>

# %%
ax = sns.histplot(dados.Cor, kde = False)
ax.figure.set_size_inches(10,6)
ax.set_title("Distruição de frequência - Cor")
ax.set_xlabel("Cor",fontsize = 14)
ax
# Out:
# <Axes: title={'center': 'Distruição de frequência - Cor'}, xlabel='Cor', ylabel='Count'>

# %%
dis_fre_quantitativas_rend
# Out:
#        Frequencia  Porcentagem (%)
# Renda
# E           49755         0.649704
# D           16700         0.218070
# C            7599         0.099228
# B            2178         0.028440
# A             349         0.004557

# %%
dis_fre_quantitativas_rend ['Frequencia'].plot.bar(width = 1, color = 'blue',alpha = 0.2, figsize = (12,6))
# Out:
# <Axes: xlabel='Renda'>

# %% [markdown]
# # <font color=green>3 MEDIDAS DE TENDÊNCIA CENTRAL</font>
# ***

# %% [markdown]
# ## DataFrame de exemplo

# %%
df = pd.DataFrame(data = {'Fulano': [8, 10 ,4, 8, 6, 10, 8],
                          'Beltrano': [10, 2, 0.5, 8,3, 9.5, 10,],
                          'Sicrano': [7.5, 8, 7, 8, 8, 8.5,7]},
                  index = ['Matemática',
                           'Português',
                           'Inglês',
                           'Geografia',
                           'História',
                           'Física',
                           'Química'])
df.rename_axis('Matérias', axis = 'columns',inplace = True)
df
# Out:
# Matérias    Fulano  Beltrano  Sicrano
# Matemática       8      10.0      7.5
# Português       10       2.0      8.0
# Inglês           4       0.5      7.0
# Geografia        8       8.0      8.0
# História         6       3.0      8.0
# Física          10       9.5      8.5
# Química          8      10.0      7.0

# %% [markdown]
# ## <font color=green>3.1 Média aritmética</font>
# ***
#
# É representada por $\mu$ quando se refere à população e por $\bar{X}$ quando se refere à amostra
#
# # $$\mu = \frac 1n\sum_{i=1}^{n}X_i$$
#
# onde
#
# $n$ = número de observações (registros)
#
# $X_i$ = valor da i-ésima observação (registro)

# %%
df['Fulano'].mean()
# Out:
# np.float64(7.714285714285714)

# %%
dados.Renda.mean()
# Out:
# np.float64(2000.3831988547631)

# %%
dados.groupby(["Sexo"])["Renda"].mean()
# Out:
# Sexo
# 0    2192.441596
# 1    1566.847393
# Name: Renda, dtype: float64

# %%
dataset = pd.DataFrame({
    'Sexo': ['H', 'M', 'M', 'M', 'H', 'H', 'H', 'M', 'M', 'H'],
    'Idade': [53, 72,54,27,30,40,58,32,44,51]
})
# Out:
#   Sexo  Idade
# 0    H     53
# 1    M     72
# 2    M     54
# 3    M     27
# 4    H     30
# 5    H     40
# 6    H     58
# 7    M     32
# 8    M     44
# 9    H     51

# %%
dataset.groupby(["Sexo"])["Idade"].mean()
# Out:
# Sexo
# H    46.4
# M    45.8
# Name: Idade, dtype: float64

# %%
dataset.groupby("Sexo").mean().loc['H']
# Out:
# Idade    46.4
# Name: H, dtype: float64

# %%
dataset["Idade"].mean()
# Out:
# np.float64(46.1)

# %% [markdown]
# ## <font color=green>3.2 Mediana</font>
# ***
#
# Para obtermos a mediana de uma conjunto de dados devemos proceder da seguinte maneira:
# 1. Ordenar o conjunto de dados;
# 2. Identificar o número de observações (registros) do conjunto de dados ($n$);
# 3. Identicar o elemento mediano:
#
# > Quando $n$ for ímpar, a posição do elemento mediano será obtida da seguinte forma:
#
#
# # $$Elemento_{Md} = \frac{n+1}2$$
#
# > Quando $n$ for par, a posição do elemento mediano será obtida da seguinte forma:
#
#
# # $$Elemento_{Md} = \frac{n}2$$
#
# 4. Obter a mediana:
#
# > Quando $n$ for ímpar:
#
#
# # $$Md = X_{Elemento_{Md}}$$
#
# > Quando $n$ for par:
#
#
# # $$Md = \frac{X_{Elemento_{Md}} + X_{Elemento_{Md}+1}}2$$
# ***

# %% [markdown]
# ### Exemplo 1 - n ímpar
#
# <img src='https://caelum-online-public.s3.amazonaws.com/1177-estatistica-parte1/01/img002.png' width='40%' style="float:left">

# %%
df = pd.DataFrame(data = {'Fulano': [8, 10 ,4, 8, 6, 10, 8],
                          'Beltrano': [10, 2, 0.5, 8,3, 9.5, 10,],
                          'Sicrano': [7.5, 8, 7, 8, 8, 8.5,7]},
                  index = ['Matemática',
                           'Português',
                           'Inglês',
                           'Geografia',
                           'História',
                           'Física',
                           'Química'])
df.rename_axis(index='Matérias', axis = 'columns',inplace = True)
df
# Out:
#             Fulano  Beltrano  Sicrano
# Matérias
# Matemática       8      10.0      7.5
# Português       10       2.0      8.0
# Inglês           4       0.5      7.0
# Geografia        8       8.0      8.0
# História         6       3.0      8.0
# Física          10       9.5      8.5
# Química          8      10.0      7.0

# %%
notas_fulano = df.Fulano
notas_fulano = notas_fulano.sort_values()
notas_fulano
# Out:
# Matérias
# Inglês         4
# História       6
# Geografia      8
# Matemática     8
# Química        8
# Português     10
# Física        10
# Name: Fulano, dtype: int64

# %%
notas_fulano = notas_fulano.reset_index()
notas_fulano
# Out:
#      Matérias  Fulano
# 0      Inglês       4
# 1    História       6
# 2   Geografia       8
# 3  Matemática       8
# 4     Química       8
# 5   Português      10
# 6      Física      10

# %%
n = notas_fulano.shape[0]
n
# Out:
# 7

# %%
elemento_md = (n+1)/2
elemento_md
# Out:
# 4.0

# %%
notas_fulano.loc[elemento_md - 1]
# Out:
# Matérias    Matemática
# Fulano               8
# Name: 3, dtype: object

# %%
notas_fulano.median
# Out:
# <bound method DataFrame.median of      Matérias  Fulano
# 0      Inglês       4
# 1    História       6
# 2   Geografia       8
# 3  Matemática       8
# 4     Química       8
# 5   Português      10
# 6      Física      10>

# %% [markdown]
# ### Exemplo 2 - n par
#
# <img src='https://caelum-online-public.s3.amazonaws.com/1177-estatistica-parte1/01/img003.png' width='50%' style="float:left">

# %%
notas_sicrano = df.Sicrano.sample(7,random_state=101)
notas_sicrano
# Out:
# Matérias
# Matemática    7.5
# Inglês        7.0
# Física        8.5
# História      8.0
# Química       7.0
# Português     8.0
# Geografia     8.0
# Name: Sicrano, dtype: float64

# %%
notas_sicrano.median()
# Out:
# 8.0

# %% [markdown]
# ### Obtendo a mediana em nosso dataset

# %%
dados.Renda.median()
# Out:
# 1200.0

# %%
dados.Renda.quantile()
# Out:
# np.float64(1200.0)

# %% [markdown]
# ## <font color=green>3.3 Moda</font>
# ***
#
# Pode-se definir a moda como sendo o valor mais frequente de um conjunto de dados. A moda é bastante utilizada para dados qualitativos.

# %%
df
# Out:
#             Fulano  Beltrano  Sicrano
# Matérias
# Matemática       8      10.0      7.5
# Português       10       2.0      8.0
# Inglês           4       0.5      7.0
# Geografia        8       8.0      8.0
# História         6       3.0      8.0
# Física          10       9.5      8.5
# Química          8      10.0      7.0

# %%
df.mode()
# Out:
#    Fulano  Beltrano  Sicrano
# 0       8      10.0      8.0

# %% [markdown]
# ### Obtendo a moda em nosso dataset

# %% [markdown]
# ## <font color=green>3.4 Relação entre média, mediana e moda</font>
# ***

# %% [markdown]
# <img src='https://caelum-online-public.s3.amazonaws.com/1177-estatistica-parte1/01/img004.png' width='80%'>

# %% [markdown]
# ### Avaliando a variável RENDA

# %%
ax = sns.histplot(dados.query('Renda < 20000').Renda)
ax.figure.set_size_inches(12,6)
ax
# Out:
# <Axes: xlabel='Renda', ylabel='Count'>

# %%
Moda = dados.Renda.mode()[0]
Moda
# Out:
# np.int64(788)

# %%
Mediana = dados.Renda.median()
Mediana
# Out:
# 1200.0

# %%
Media = dados.Renda.mean()
Media
# Out:
# np.float64(2000.3831988547631)

# %% [markdown]
# ***

# %%
import seaborn as sns

# %%
ax = sns.histplot(dados.Altura)
ax.figure.set_size_inches(12,6)
ax
# Out:
# <Axes: xlabel='Altura', ylabel='Count'>

# %% [markdown]
# ### Avaliando a variável ALTURA

# %%
Moda = dados.Altura.mode(0)
Moda
# Out:
# 0    1.568128
# 1    1.671225
# 2    1.681659
# 3    1.692977
# 4    1.708163
# 5    1.708370
# 6    1.753842
# 7    1.779073
# 8    1.796462
# Name: Altura, dtype: float64

# %%
Mediana = dados.Altura.median()
Mediana
# Out:
# 1.6993247325

# %%
Media = dados.Altura.mean()
Media
# Out:
# np.float64(1.6995124540575741)

# %% [markdown]
# ***

# %% [markdown]
# ### Avaliando a variável ANOS DE ESTUDO

# %%
ax = sns.histplot(dados['Anos de Estudo'],bins = 17)
ax.figure.set_size_inches(12,6)
ax
# Out:
# <Axes: xlabel='Anos de Estudo', ylabel='Count'>

# %%
Moda = dados['Anos de Estudo'].mode()[0]
Moda
# Out:
# np.int64(12)

# %%
Mediana = dados['Anos de Estudo'].median()
Mediana
# Out:
# 11.0

# %%
Media = dados['Anos de Estudo'].mean()
Media
# Out:
# np.float64(9.469664237376367)

# %% [markdown]
# # <font color=green>4 MEDIDAS SEPARATRIZES</font>
# ***

# %% [markdown]
# ## <font color=green>4.1 Quartis, decis e percentis</font>
# ***
#
# Há uma série de medidas de posição semelhantes na sua concepção à mediana, embora não sejam medidas de tendência central. Como se sabe, a mediana divide a distribuição em duas partes iguais quanto ao número de elementos de cada parte. Já os quartis permitem dividir a distribuição em quatro partes iguais quanto ao número de elementos de cada uma; os decis em dez partes e os centis em cem partes iguais.

# %% [markdown]
# ## <font color=green>4.2 Box-plot</font>
# ***
#
# O box plot dá uma idéia da posição, dispersão, assimetria, caudas e dados discrepantes (outliers). A posição central é dada pela mediana e a dispersão por $IIQ$. As posições relativas de $Q1$, $Mediana$ e $Q3$ dão uma noção da simetria da distribuição. Os comprimentos das cauda são dados pelas linhas que vão do retângulo aos valores remotos e pelos valores atípicos.

# %% [markdown]
# <img src='https://caelum-online-public.s3.amazonaws.com/1177-estatistica-parte1/01/img005.png' width='65%'>

# %% [markdown]
# <img src='https://caelum-online-public.s3.amazonaws.com/1177-estatistica-parte1/01/img006.png' width='80%'>

# %% [markdown]
# # <font color=green>5 MEDIDAS DE DISPERSÃO</font>
# ***
#
# Embora as medidas de posição forneçam uma sumarização bastante importante dos dados, elas podem não ser suficientes para caracterizar conjuntos distintos, especialmente quando as observações de determinada distribuição apresentarem dados muito dispersos.

# %% [markdown]
# ## <font color=green>5.1 Desvio médio absoluto</font>
# ***
#
#
# # $$DM = \frac 1n\sum_{i=1}^{n}|X_i-\bar{X}|$$

# %% [markdown]
# ## <font color=green>5.2 Variância</font>
# ***

# %% [markdown]
# ### Variância
#
# A variância é construída a partir das diferenças entre cada observação e a média dos dados, ou seja, o desvio em torno da média. No cálculo da variância, os desvios em torno da média são elevados ao quadrado.

# %% [markdown]
# ### Variância populacional
#
# # $$\sigma^2 = \frac 1n\sum_{i=1}^{n}(X_i-\mu)^2$$

# %% [markdown]
# ### Variância amostral
#
# # $$S^2 = \frac 1{n-1}\sum_{i=1}^{n}(X_i-\bar{X})^2$$

# %% [markdown]
# ## <font color=green>5.3 Desvio padrão</font>
# ***
#
# Uma das restrições da variância é o fato de fornecer medidas em quadrados das unidades originais - a variância de medidas de comprimento, por exemplo, é em unidades de área. Logo, o fato de as unidades serem diferentes dificulta a comparação da dispersão com as variáveis que a definem. Um modo de eliminar essa dificuldade é considerar sua raiz quadrada.

# %% [markdown]
# ### Desvio padrão populacional
#
# # $$\sigma = \sqrt{\frac 1n\sum_{i=1}^{n}(X_i-\mu)^2} \Longrightarrow \sigma = \sqrt{\sigma^2}$$

# %% [markdown]
# ### Desvio padrão amostral
#
# # $$S = \sqrt{\frac 1{n-1}\sum_{i=1}^{n}(X_i-\bar{X})^2} \Longrightarrow S = \sqrt{S^2}$$
